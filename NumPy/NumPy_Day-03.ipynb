# %%
def factorial(n):
    if n == 1:
        return 1 
    else:
        return n * factorial(n - 1)
    
factorial(5)
# Out:
# 120

# %%
def hello(n):
    if n <= 0:
        return
    print("Hello")
    hello(n - 1)

hello(4)
# Out:
# Hello
# Hello
# Hello
# Hello
